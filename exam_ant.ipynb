# %%
# 어노테이션 : 어떤 자료형인지 미리 적어두는 표시 
age : int= 30
print(age)
# 어노테이션은 강제 규칙이 아니다.
age : int ="안녕"
print(age)


def add(a:int, b:int) -> int:
    return a+b

print(add(1,20))
print(add('가나','다라'))



# - 리스트
nums:list[int]=[1,2,3]

# - 딕셔너리
person:dict[str,int]={
    "age":25,
    "height":180
    
}

print(nums)
print(person)
# Out:
# 30
# 안녕
# 21
# 가나다라
# [1, 2, 3]
# {'age': 25, 'height': 180}
