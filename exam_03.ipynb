# %% [markdown]
# # 문제 : 리스트에 순서대로 2, 1, 5, 6, 7를 한 번에 담아주세요.

# %%
list=[2,1,5,6,7]
print(list)
# Out:
# [2, 1, 5, 6, 7]

# %% [markdown]
# # 문제 : 비어있는 리스트를 만들고, 순서대로 2, 1, 5, 6, 7를 하나씩 담아주세요.

# %%
list=[]
list.append(2)
list.append(1)
list.append(5)
list.append(6)
list.append(7)
print(list)
# Out:
# [2, 1, 5, 6, 7]

# %% [markdown]
# # 문제 - 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 가장 마지막 요소를 출력해주세요.

# %%
list=['월', '화', '수', '목', '금']
print(list[-1])
# Out:
# 금

# %% [markdown]
# 문제 - 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 while문을 이용해서 요소 전부 출력해주세요

# %%
list=['월', '화', '수', '목', '금']
i=0
while(True):
   print(list[i])
   i=i+1
   if(i==len(list)): break
# Out:
# 월
# 화
# 수
# 목

# %% [markdown]
# 문제 - 리스트에 순서대로 2, 1, '오', 6, 7를 한번에 담아주세요. 그리고 리스트 안에 있는 '오'를 정수 5로 변경해주세요.

# %%
list=[1,2,'오',3,4]
list[list.index('오')]=5
print(list)
# Out:
# [1, 2, 5, 3, 4]

# %% [markdown]
# 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. '화'가 리스트 안에 들어있는지 알려주세요.

# %%
list=['월', '화', '수', '목', '금']
if('화' in list):
    print("화 있다.")
else:
    print("없다.")
# Out:
# 없다.

# %% [markdown]
# 문제 - 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 리스트에 있는 '금'을 삭제하는 3가지 방법을 보여주세요.

# %%
list=['월', '화', '수', '목', '금']

#del list[4]
#del list[list.index('금')]
if ('금' in list):
    list.remove('금')
print(list)
# Out:
# ['월', '화', '수', '목', 'ㄹ']

# %%
ages={
    "a":10,
    "b":20,
    "c":30
}

for name in ages.keys():
    age=ages[name]
    print(name,age)

for name in ages.values():
    print(name)
# Out:
# a 10
# b 20
# c 30
# 10
# 20
# 30

# %% [markdown]
# # 문제 : 딕셔너리에 각 달의 마지막 날들을 한번에 담기

# %%
month={
    "1월": 31,
    "2월": 31,
    "3월": 31,
    "4월": 31,
    "5월": 31,
    "6월": 31,
    "7월": 31,
    "8월": 31,
    "9월": 31,
    "10월": 31,
    "11월": 31,
    "12월": 31
}
print(month)
# Out:
# {'1월': 31, '2월': 31, '3월': 31, '4월': 31, '5월': 31, '6월': 31, '7월': 31, '8월': 31, '9월': 31, '10월': 31, '11월': 31, '12월': 31}

# %% [markdown]
# 문제 - 딕셔너리에 각 달의 마지막 날들을 반복문을 통해 담기

# %%
month_day={
}

for i in range(1,13):
    end_day=31

    if( i in [1,2,3,4]):
        end_day
    month=str(i)+"월"
    month_day[month]=end_day
print(month_day)
# Out:
# {'1월': 28, '2월': 28, '3월': 28, '4월': 28, '5월': 31, '6월': 31, '7월': 31, '8월': 31, '9월': 31, '10월': 31, '11월': 31, '12월': 31}
